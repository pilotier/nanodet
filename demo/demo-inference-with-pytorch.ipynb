# %% [markdown]
# # How to Load Nanodet in PyTorch
#
# This article is an introductory tutorial to infer nanodet with PyTorch.
#
# **Note**, we suppose this notebook is in the root directory of nonadet!
#
# ## Install nanodet first
#
# For us to begin with, PyTorch should be installed. TorchVision is also required since we will be using it as our model zoo.
#
# A quick solution is to install via pip
#
# ```shell
# pip install torch==1.7.1
# pip install torchvision==0.8.2
# ```
#
# or please refer to official site https://pytorch.org/get-started/locally/
#
# PyTorch versions should be backwards compatible but should be used with the proper TorchVision version.
#
# And then don't forget to install other dependencies.
#
# ```shell
# pip install -r requirements.txt
# ```
#
# Next enter the key part, let's install `nanodet`!
#
# ```shell
# python setup.py develop
# ```
#
# ## Set Environmental Parameters

# %%
import os
import cv2
import torch

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

device = torch.device('cuda')

# %%
import sys
path = "/media/navya/vol/projects/nanodet/"
sys.path.append(path)

# %%
torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark = True

# %% [markdown]
# ## Set Model Configuration and Logger

# %%
from nanodet.util import cfg, load_config, Logger

# %%
# config_path = path + 'config/nanodet-plus-m_320.yml'
# model_path = path + 'workspace/nanodet_m/nanodet-plus-m_320.pth'

config_path = path + 'config/nanodet-plus-m-1.5x_416.yml'
model_path = path + 'workspace/nanodet_m/nanodet-plus-m-1.5x_416.pth'

image_path = path + 'demo_mnn/imgs/000252.jpg'

# %%
load_config(cfg, config_path)
logger = Logger(-1, use_tensorboard=False)

# %% [markdown]
# ## Set Model Predictor

# %%
from demo import Predictor

# %%
predictor = Predictor(cfg, model_path, logger, device=device)
# Out:
# model size is  1.5x
# init weights...
# Finish initialize NanoDet-Plus Head.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.0.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.0.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.0.bn.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.0.bn.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.0.bn.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.0.bn.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.0.bn.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.0.bn.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.0.bn.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.0.bn.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.0.bn.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.0.bn.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.1.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.1.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.1.bn.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.1.bn.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.1.bn.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.1.bn.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.1.bn.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.1.bn.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.1.bn.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.1.bn.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.1.bn.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.1.bn.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.2.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.2.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.2.bn.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.2.bn.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.2.bn.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.2.bn.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.2.bn.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.2.bn.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.2.bn.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.2.bn.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.2.bn.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.reduce_layers.2.bn.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.primary_conv.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.primary_conv.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.primary_conv.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.primary_conv.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.primary_conv.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.primary_conv.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.primary_conv.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.primary_conv.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.primary_conv.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.primary_conv.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.primary_conv.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.primary_conv.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.cheap_operation.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.cheap_operation.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.cheap_operation.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.cheap_operation.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.cheap_operation.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.cheap_operation.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.cheap_operation.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.cheap_operation.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.cheap_operation.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.cheap_operation.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.cheap_operation.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost1.cheap_operation.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.primary_conv.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.primary_conv.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.primary_conv.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.primary_conv.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.primary_conv.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.primary_conv.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.primary_conv.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.primary_conv.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.primary_conv.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.primary_conv.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.primary_conv.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.primary_conv.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.cheap_operation.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.cheap_operation.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.cheap_operation.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.cheap_operation.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.cheap_operation.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.cheap_operation.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.cheap_operation.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.cheap_operation.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.cheap_operation.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.cheap_operation.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.cheap_operation.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.ghost2.cheap_operation.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.2.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.2.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.3.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.3.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.3.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.3.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.3.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.3.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.3.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.3.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.3.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.0.blocks.0.shortcut.3.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.primary_conv.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.primary_conv.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.primary_conv.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.primary_conv.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.primary_conv.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.primary_conv.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.primary_conv.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.primary_conv.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.primary_conv.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.primary_conv.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.primary_conv.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.primary_conv.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.cheap_operation.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.cheap_operation.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.cheap_operation.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.cheap_operation.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.cheap_operation.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.cheap_operation.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.cheap_operation.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.cheap_operation.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.cheap_operation.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.cheap_operation.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.cheap_operation.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost1.cheap_operation.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.primary_conv.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.primary_conv.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.primary_conv.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.primary_conv.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.primary_conv.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.primary_conv.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.primary_conv.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.primary_conv.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.primary_conv.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.primary_conv.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.primary_conv.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.primary_conv.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.cheap_operation.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.cheap_operation.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.cheap_operation.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.cheap_operation.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.cheap_operation.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.cheap_operation.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.cheap_operation.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.cheap_operation.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.cheap_operation.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.cheap_operation.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.cheap_operation.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.ghost2.cheap_operation.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.2.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.2.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.3.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.3.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.3.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.3.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.3.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.3.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.3.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.3.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.3.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.top_down_blocks.1.blocks.0.shortcut.3.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.depthwise.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.depthwise.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.pointwise.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.pointwise.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.dwnorm.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.dwnorm.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.dwnorm.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.dwnorm.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.dwnorm.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.dwnorm.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.dwnorm.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.dwnorm.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.dwnorm.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.dwnorm.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.pwnorm.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.pwnorm.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.pwnorm.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.pwnorm.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.pwnorm.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.pwnorm.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.pwnorm.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.pwnorm.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.pwnorm.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.0.pwnorm.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.depthwise.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.depthwise.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.pointwise.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.pointwise.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.dwnorm.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.dwnorm.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.dwnorm.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.dwnorm.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.dwnorm.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.dwnorm.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.dwnorm.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.dwnorm.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.dwnorm.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.dwnorm.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.pwnorm.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.pwnorm.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.pwnorm.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.pwnorm.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.pwnorm.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.pwnorm.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.pwnorm.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.pwnorm.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.pwnorm.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.downsamples.1.pwnorm.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.primary_conv.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.primary_conv.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.primary_conv.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.primary_conv.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.primary_conv.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.primary_conv.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.primary_conv.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.primary_conv.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.primary_conv.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.primary_conv.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.primary_conv.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.primary_conv.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.cheap_operation.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.cheap_operation.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.cheap_operation.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.cheap_operation.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.cheap_operation.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.cheap_operation.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.cheap_operation.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.cheap_operation.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.cheap_operation.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.cheap_operation.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.cheap_operation.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost1.cheap_operation.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.primary_conv.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.primary_conv.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.primary_conv.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.primary_conv.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.primary_conv.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.primary_conv.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.primary_conv.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.primary_conv.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.primary_conv.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.primary_conv.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.primary_conv.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.primary_conv.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.cheap_operation.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.cheap_operation.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.cheap_operation.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.cheap_operation.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.cheap_operation.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.cheap_operation.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.cheap_operation.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.cheap_operation.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.cheap_operation.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.cheap_operation.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.cheap_operation.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.ghost2.cheap_operation.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.2.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.2.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.3.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.3.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.3.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.3.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.3.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.3.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.3.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.3.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.3.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.0.blocks.0.shortcut.3.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.primary_conv.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.primary_conv.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.primary_conv.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.primary_conv.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.primary_conv.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.primary_conv.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.primary_conv.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.primary_conv.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.primary_conv.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.primary_conv.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.primary_conv.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.primary_conv.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.cheap_operation.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.cheap_operation.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.cheap_operation.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.cheap_operation.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.cheap_operation.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.cheap_operation.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.cheap_operation.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.cheap_operation.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.cheap_operation.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.cheap_operation.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.cheap_operation.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost1.cheap_operation.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.primary_conv.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.primary_conv.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.primary_conv.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.primary_conv.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.primary_conv.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.primary_conv.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.primary_conv.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.primary_conv.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.primary_conv.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.primary_conv.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.primary_conv.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.primary_conv.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.cheap_operation.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.cheap_operation.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.cheap_operation.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.cheap_operation.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.cheap_operation.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.cheap_operation.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.cheap_operation.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.cheap_operation.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.cheap_operation.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.cheap_operation.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.cheap_operation.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.ghost2.cheap_operation.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.0.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.1.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.1.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.1.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.1.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.1.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.2.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.2.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.3.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.3.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.3.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.3.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.3.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.3.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.3.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.3.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.3.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.bottom_up_blocks.1.blocks.0.shortcut.3.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.depthwise.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.depthwise.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.pointwise.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.pointwise.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.dwnorm.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.dwnorm.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.dwnorm.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.dwnorm.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.dwnorm.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.dwnorm.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.dwnorm.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.dwnorm.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.dwnorm.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.dwnorm.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.pwnorm.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.pwnorm.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.pwnorm.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.pwnorm.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.pwnorm.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.pwnorm.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.pwnorm.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.pwnorm.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.pwnorm.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_in_conv.0.pwnorm.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.depthwise.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.depthwise.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.pointwise.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.pointwise.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.dwnorm.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.dwnorm.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.dwnorm.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.dwnorm.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.dwnorm.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.dwnorm.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.dwnorm.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.dwnorm.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.dwnorm.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.dwnorm.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.pwnorm.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.pwnorm.weight.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.pwnorm.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.pwnorm.bias.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.pwnorm.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.pwnorm.running_mean.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.pwnorm.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.pwnorm.running_var.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.pwnorm.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_fpn.extra_lvl_out_conv.0.pwnorm.num_batches_tracked.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.0.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.0.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.0.gn.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.0.gn.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.0.gn.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.0.gn.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.1.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.1.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.1.gn.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.1.gn.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.1.gn.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.1.gn.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.2.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.2.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.2.gn.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.2.gn.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.2.gn.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.2.gn.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.3.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.3.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.3.gn.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.3.gn.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.3.gn.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.cls_convs.3.gn.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.0.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.0.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.0.gn.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.0.gn.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.0.gn.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.0.gn.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.1.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.1.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.1.gn.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.1.gn.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.1.gn.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.1.gn.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.2.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.2.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.2.gn.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.2.gn.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.2.gn.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.2.gn.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.3.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.3.conv.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.3.gn.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.3.gn.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.3.gn.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.reg_convs.3.gn.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.gfl_cls.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.gfl_cls.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.gfl_cls.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.gfl_cls.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.gfl_reg.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.gfl_reg.weight.
# [root][05-16 15:23:17]INFO:No param aux_head.gfl_reg.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.gfl_reg.bias.
# [root][05-16 15:23:17]INFO:No param aux_head.scales.0.scale.
# [root][05-16 15:23:17]INFO:No param aux_head.scales.0.scale.
# [root][05-16 15:23:17]INFO:No param aux_head.scales.1.scale.
# [root][05-16 15:23:17]INFO:No param aux_head.scales.1.scale.
# [root][05-16 15:23:17]INFO:No param aux_head.scales.2.scale.
# [root][05-16 15:23:17]INFO:No param aux_head.scales.2.scale.
# [root][05-16 15:23:17]INFO:No param aux_head.scales.3.scale.
# [root][05-16 15:23:17]INFO:No param aux_head.scales.3.scale.

# %%
img = "/media/navya/vol/data/StopLightV2/val/L/_000141.jpeg"

# %%
meta, res = predictor.inference(img)
# Out:
# torch.Size([1, 3598, 112])
# forward time: 0.109s | decode time: 0.005s |

# %% [markdown]
# ## Detection output visualisation

# %%
from nanodet.util import overlay_bbox_cv

from IPython.display import display
from PIL import Image

def cv2_imshow(a, convert_bgr_to_rgb=True):
    """A replacement for cv2.imshow() for use in Jupyter notebooks.
    Args:
        a: np.ndarray. shape (N, M) or (N, M, 1) is an NxM grayscale image. shape
            (N, M, 3) is an NxM BGR color image. shape (N, M, 4) is an NxM BGRA color
            image.
        convert_bgr_to_rgb: switch to convert BGR to RGB channel.
    """
    a = a.clip(0, 255).astype('uint8')
    # cv2 stores colors as BGR; convert to RGB
    if convert_bgr_to_rgb and a.ndim == 3:
        if a.shape[2] == 4:
            a = cv2.cvtColor(a, cv2.COLOR_BGRA2RGBA)
        else:
            a = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
    display(Image.fromarray(a))

# %%
print(res[0][1])
# Out:
# [[965.6704711914062, 186.48411560058594, 1021.306884765625, 251.2124481201172, 0.1389537751674652], [980.822265625, 185.69876098632812, 1041.4730224609375, 265.39813232421875, 0.11144839227199554]]

# %%
result = overlay_bbox_cv(meta['raw_img'][0], res[0], cfg.class_names, score_thresh=0.20)

# %%
imshow_scale = 1.0
cv2_imshow(cv2.resize(result, None, fx=imshow_scale, fy=imshow_scale))
# Out:
# <PIL.Image.Image image mode=RGB size=1280x384 at 0x7F384D9070D0>
